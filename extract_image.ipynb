# %%
import glob
import os
for image in glob.glob('video'+'/*.mp4'):
    name_fol=image.split('.')[0].split('\\')[-1]
    os.mkdir('demo'+'/'+name_fol)

# %%
# !python extract_image.py -i video -s demo
# Out:
# 0
# [INFO] saved demo\0\0_0.png to disk
# [INFO] saved demo\0\0_2.png to disk
# [INFO] saved demo\0\0_4.png to disk
# [INFO] saved demo\0\0_6.png to disk
# [INFO] saved demo\0\0_8.png to disk
# [INFO] saved demo\0\0_10.png to disk
# [INFO] saved demo\0\0_12.png to disk
# [INFO] saved demo\0\0_14.png to disk
# [INFO] saved demo\0\0_16.png to disk
# [INFO] saved demo\0\0_18.png to disk
# [INFO] saved demo\0\0_20.png to disk
# [INFO] saved demo\0\0_22.png to disk
# [INFO] saved demo\0\0_24.png to disk
# [INFO] saved demo\0\0_26.png to disk
# [INFO] saved demo\0\0_28.png to disk
# [INFO] saved demo\0\0_30.png to disk
# [INFO] saved demo\0\0_32.png to disk
# [INFO] saved demo\0\0_34.png to disk
# [INFO] saved demo\0\0_36.png to disk
# [INFO] saved demo\0\0_38.png to disk
# [INFO] saved demo\0\0_40.png to disk
# [INFO] saved demo\0\0_42.png to disk
# [INFO] saved demo\0\0_44.png to disk
# [INFO] saved demo\0\0_46.png to disk
# [INFO] saved demo\0\0_48.png to disk
# ...

# %%
import random
def random_choice(mang,dai):
  mang=[]
  while (len(mang)<dai):
    rand=random.randint(1, len(images))
    if len(mang)<1:
      mang.append(rand)
    else:
      if rand not in mang:
        mang.append(rand)   
  return mang

# %%
a=[]
b=[]
for usr in os.listdir('demo'):
    print(usr)
    dem=[]
    for image in glob.glob(os.path.join('demo', usr)+'/*.png'):
        #os.remove(image)
        dem.append(image)
    b.append(len(dem))
    a.append(dem)
# Out:
# 0
# 15
# 4

# %%
len(a)
# Out:
# 3

# %%
b
# Out:
# [152, 152, 152]

# %%
mang1=[]
for i in range(len(a)):
    mang1.append(random_choice(mang,b[i]-100))
print(mang1)
# Out:
# [[9, 69, 37, 29, 71, 149, 52, 115, 73, 17, 2, 117, 135, 112, 146, 18, 74, 45, 57, 133, 84, 15, 148, 47, 20, 113, 24, 38, 59, 72, 141, 23, 144, 11, 128, 26, 4, 60, 102, 22, 132, 85, 97, 99, 87, 78, 49, 131, 88, 58, 142, 19], [152, 73, 108, 134, 6, 106, 93, 105, 149, 66, 131, 17, 117, 116, 58, 69, 30, 88, 10, 111, 56, 80, 74, 150, 72, 112, 107, 133, 9, 141, 57, 94, 25, 2, 148, 99, 124, 92, 113, 139, 13, 48, 126, 91, 60, 109, 67, 121, 123, 151, 51, 146], [142, 54, 152, 150, 95, 21, 86, 132, 2, 20, 141, 62, 85, 100, 111, 97, 110, 102, 106, 30, 93, 59, 6, 78, 58, 18, 82, 114, 146, 77, 143, 36, 13, 103, 130, 27, 129, 148, 10, 40, 63, 99, 75, 61, 55, 43, 29, 127, 74, 53, 104, 60]]

# %%
for j in range(len(mang1)):
    dem=0
    for i in range(len(mang1[j])):
        print(a[j][i])
        os.remove(a[j][i])
        dem+=1
    print(dem)
# Out:
# demo\0\0_0.png
# demo\0\0_10.png
# demo\0\0_100.png
# demo\0\0_102.png
# demo\0\0_104.png
# demo\0\0_106.png
# demo\0\0_108.png
# demo\0\0_110.png
# demo\0\0_112.png
# demo\0\0_114.png
# demo\0\0_116.png
# demo\0\0_118.png
# demo\0\0_12.png
# demo\0\0_120.png
# demo\0\0_122.png
# demo\0\0_124.png
# demo\0\0_126.png
# demo\0\0_128.png
# demo\0\0_130.png
# demo\0\0_132.png
# demo\0\0_134.png
# demo\0\0_136.png
# demo\0\0_138.png
# demo\0\0_14.png
# demo\0\0_140.png
# demo\0\0_142.png
# demo\0\0_144.png
# demo\0\0_146.png
# demo\0\0_148.png
# demo\0\0_150.png
# demo\0\0_152.png
# demo\0\0_154.png
# demo\0\0_156.png
# demo\0\0_158.png
# demo\0\0_16.png
# demo\0\0_160.png
# demo\0\0_162.png
# demo\0\0_164.png
# demo\0\0_166.png
# demo\0\0_168.png
# demo\0\0_170.png
# demo\0\0_172.png
# demo\0\0_174.png
# demo\0\0_176.png
# demo\0\0_178.png
# demo\0\0_18.png
# demo\0\0_180.png
# demo\0\0_182.png
# demo\0\0_184.png
# demo\0\0_186.png
# demo\0\0_188.png
# demo\0\0_190.png
# 52
# ...

# %%
for image in glob.glob('video'+'/*.mp4'):
    print(image)
    print(image.split('.')[0].split('\\')[-1])
# Out:
# video\0.mp4
# 0
# video\15.mp4
# 15
# video\4.mp4
# 4
